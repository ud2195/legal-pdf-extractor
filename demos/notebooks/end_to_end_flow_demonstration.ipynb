# %%
from legal_pdf_extractor import extract
from pathlib import Path

result = extract(
    pdf=Path('/Users/ud2195/legal-pdf-extractor/CUAD_v1/full_contract_pdf/Part_I/License_Agreements/GopageCorp_20140221_10-K_EX-10.1_8432966_EX-10.1_Content License Agreement.pdf'),
    query="what is the agreement date ?",
    output_type="array[string]",
)

result
# Out:
# Loading weights:   0%|          | 0/770 [00:00<?, ?it/s]
# {'value': ['2014-02-10'],
#  'found': True,
#  'sources': [{'page': 1,
#    'snippet': 'This Content License Agreement (" Agreement "), dated as of Feb 10, 2014 (the " Effective Date "), is by and between PSiTech Corporation , a BVI Corporation, with offices located at 303, 3 rd Fl, St. Georges Bldg, 2 Ice House St, Central, Hong Kong(" Licensor "), and Empirical Ventures, Inc. , a Nevada corporation with offices located at 100, 40 Lake Bellevue Dr, Bellevue, WA(" Licensee ").'}]}

# %%
result = extract(
    pdf=Path('/Users/ud2195/legal-pdf-extractor/CUAD_v1/full_contract_pdf/Part_I/Affiliate_Agreements/CybergyHoldingsInc_20140520_10-Q_EX-10.27_8605784_EX-10.27_Affiliate Agreement.pdf'),
    query="what are the parties involved ?",
    output_type="string",
)

result
# Out:
# {'value': 'BIRCH FIRST INVESTMENTS INC. and MOUNT KNOWLEDGE HOLDINGS INC.',
#  'found': True,
#  'sources': [{'page': 14,
#    'snippet': 'COMPANY MA\nBIRCH FIRST INVESTMENTS INC. A US Virgin Islands corporation MOUNT KNOWLEDGE HOLDINGS INC. A Nevada corporation'}]}

# %%
result = extract(
    pdf=Path('/Users/ud2195/legal-pdf-extractor/CUAD_v1/full_contract_pdf/Part_I/License_Agreements/FulucaiProductionsLtd_20131223_10-Q_EX-10.9_8368347_EX-10.9_Content License Agreement.pdf'),
    query="what is name of the document ?",
    output_type="string",
)

result
# Out:
# {'value': 'CONTENT DISTRIBUTION AND LICENSE AGREEMENT',
#  'found': True,
#  'sources': [{'page': 1,
#    'snippet': "This\xa0CONTENT\xa0DISTRIBUTION\xa0AND\xa0LICENSE\xa0AGREEMENT\xa0(the\xa0' Agreement ')\xa0is\xa0entered\xa0into\xa0as\xa0of\xa0November\xa015,\xa02012"}]}
