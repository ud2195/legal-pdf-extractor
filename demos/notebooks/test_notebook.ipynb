# %% [markdown]
# # Legal PDF extractor demo
#
# Run these examples from the repository root after setting `OPENAI_API_KEY`.

# %%
from pathlib import Path

from legal_pdf_extractor import extract

PROJECT_ROOT = Path.cwd()
SAMPLE_PDFS = PROJECT_ROOT / "CUAD_v1" / "full_contract_pdf" / "Part_I"

result = extract(
    pdf=SAMPLE_PDFS / "License_Agreements" / "GopageCorp_20140221_10-K_EX-10.1_8432966_EX-10.1_Content License Agreement.pdf",
    query="what is the agreement date ?",
    output_type="array[string]",
)

result

# %%
result = extract(
    pdf=SAMPLE_PDFS / "Affiliate_Agreements" / "CybergyHoldingsInc_20140520_10-Q_EX-10.27_8605784_EX-10.27_Affiliate Agreement.pdf",
    query="what are the parties involved ?",
    output_type="string",
)

result

# %%
result = extract(
    pdf=SAMPLE_PDFS / "License_Agreements" / "FulucaiProductionsLtd_20131223_10-Q_EX-10.9_8368347_EX-10.9_Content License Agreement.pdf",
    query="what is name of the document ?",
    output_type="string",
)

result
